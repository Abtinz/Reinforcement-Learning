# %%
import torch
import torch.nn as nn

import numpy as np

torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# Optimizer -> Adam</br>
# Loss Function -> Min Square Error

# %%
from model import QNetwork, get_network_input
from Game import GameEnvironment
from collections import deque
from replay_buffer import ReplayMemory
import time

# TODO: Create an instance for model with input_dim = 10, hidden_dim = 20, output_dim = 5

model = QNetwork(input_dim=10, hidden_dim=20, output_dim=5)
epsilon = 0.1
grid_size = 15 
GAMMA = 0.9

board = GameEnvironment(grid_size, nothing=0, dead=-1, apple=1)
memory = ReplayMemory(1000)  

#adam will be our optimizer
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-5)

#min square error
MSE = nn.MSELoss()

# %% [markdown]
# # Run Episode

# %%
#this function will run our episodes due the learning
def run_episode(num_games):
    run = True
    games_played = 0
    total_reward = 0    
    episode_games = 0
    snake_len_array = []
    
    while run:
        # TODO: Get state
        state = get_network_input(board.snake, board.apple)
        
        action_0 = model(state)
        
        # TODO: Compare a random number with epsilon and find out the next action
        if np.random.rand(0,1) < epsilon:
         next_action = np.random.randint(0, 5)
        else:
         next_action = torch.argmax(action_0)

        reward, done, len_of_snake = board.update_board_state(next_action)
        
        # TODO: Get next state
        next_state = get_network_input(board.snake, board.apple)
        
        memory.push(state, next_action, reward, next_state, done)
        
        # TODO: update total reward
        total_reward += reward
        
        episode_games += 1
        
        if board.game_over:
            games_played += 1
            snake_len_array.append(len_of_snake)
            board.reset_game()
            
            if num_games == games_played:
                run = False
                
    avg_len_of_snake = np.mean(snake_len_array)
    max_len_of_snake = np.max(snake_len_array)
    return total_reward, avg_len_of_snake, max_len_of_snake

# %% [markdown]
# # Learn Section

# %%
def learn(num_updates, batch_size):
    
    total_loss = 0
    
    for i in range(num_updates):

        optimizer.zero_grad()
        sample = memory.sample(batch_size)
            
        states, actions, rewards, next_states, dones = sample
        states = torch.cat([x.unsqueeze(0) for x in states], dim=0) 
        actions = torch.LongTensor(actions) 
        rewards = torch.FloatTensor(rewards) 
        next_states = torch.cat([x.unsqueeze(0) for x in next_states]) 
        dones = torch.FloatTensor(dones) 
        
        # TODO: Get Q values for current state
        q_local = model(states)
        
        # TODO: Get Q values for next state
        next_q_value = model.forward(next_states)

        Q_expected  = q_local.gather(1, actions.unsqueeze(0).transpose(0,1)).transpose(0,1).squeeze(0)  
        
        Q_targets_next = torch.max(next_q_value, 1)[0]*(torch.ones(dones.size()) - dones)
        
        # TODO: Calculate Q targets for current state
        Q_targets  = rewards + (GAMMA * Q_targets_next)
        
        loss = MSE(Q_expected, Q_targets)
        
        total_loss += loss
        loss.backward()
        optimizer.step()
        
    return total_loss

# %%
num_episodes = 3000 
num_updates = 200 
print_every = 100
games_in_episode = 30
batch_size = 20


def train():
    
    scores_deque = deque(maxlen=100)
    scores_array = []
    avg_scores_array = []    
    
    avg_len_array = []
    avg_max_len_array = []
    
    time_start = time.time()
    
    
    for i_episode in range(num_episodes+1):
        
        # TODO: Run an episode
        score, avg_len, max_len = run_episode(games_in_episode)
        
        scores_deque.append(score)
        scores_array.append(score)
        avg_len_array.append(avg_len)
        avg_max_len_array.append(max_len)
        
        avg_score = np.mean(scores_deque)
        avg_scores_array.append(avg_score)
        
        # TODO: Learn from the episode
        total_loss = learn(num_updates, batch_size)
        
        dt = (int)(time.time() - time_start)
        
        if i_episode % print_every == 0 and i_episode > 0:
            print('Ep.: {:6}, Loss: {:.3f}, Avg.Score: {:.2f}, Avg.LenOfSnake: {:.2f}, Max.LenOfSnake:  {:.2f} Time: {:02}:{:02}:{:02} '.\
                  format(i_episode, total_loss, score, avg_len, max_len, dt//3600, dt%3600//60, dt%60))
            
        memory.truncate()
        
        if i_episode % 250 == 0 and i_episode > 0:   
            torch.save(model.state_dict(), './model/Snake_{}'.format(i_episode))
            
    return scores_array, avg_scores_array, avg_len_array, avg_max_len_array

# %%
# TODO: Train the model
scores, avg_scores, avg_len_of_snake, max_len_of_snake = train()
# Out:
# C:\Users\abt\AppData\Local\Temp\ipykernel_14540\386669960.py:16: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if np.random.rand(0,1) < epsilon:
# Ep.:    100, Loss: 2.115, Avg.Score: -27.00, Avg.LenOfSnake: 5.10, Max.LenOfSnake:  6.00 Time: 00:01:48
# Ep.:    200, Loss: 1.225, Avg.Score: -28.00, Avg.LenOfSnake: 5.07, Max.LenOfSnake:  7.00 Time: 00:03:51
# Ep.:    300, Loss: 1.197, Avg.Score: -28.00, Avg.LenOfSnake: 5.07, Max.LenOfSnake:  6.00 Time: 00:07:44
# Ep.:    400, Loss: 1.207, Avg.Score: -28.00, Avg.LenOfSnake: 5.07, Max.LenOfSnake:  6.00 Time: 00:11:19
# Ep.:    500, Loss: 1.337, Avg.Score: -27.00, Avg.LenOfSnake: 5.10, Max.LenOfSnake:  6.00 Time: 00:14:43
# Ep.:    600, Loss: 1.046, Avg.Score: -29.00, Avg.LenOfSnake: 5.03, Max.LenOfSnake:  6.00 Time: 00:18:20
# Ep.:    700, Loss: 1.103, Avg.Score: -28.00, Avg.LenOfSnake: 5.07, Max.LenOfSnake:  6.00 Time: 00:21:56
# Ep.:    800, Loss: 1.364, Avg.Score: -28.00, Avg.LenOfSnake: 5.07, Max.LenOfSnake:  6.00 Time: 00:25:31
# Ep.:    900, Loss: 1.292, Avg.Score: -27.00, Avg.LenOfSnake: 5.10, Max.LenOfSnake:  6.00 Time: 00:29:14
# Ep.:   1000, Loss: 1.157, Avg.Score: -26.00, Avg.LenOfSnake: 5.13, Max.LenOfSnake:  6.00 Time: 00:32:59
# Ep.:   1100, Loss: 1.109, Avg.Score: -29.00, Avg.LenOfSnake: 5.03, Max.LenOfSnake:  6.00 Time: 00:36:49
# Ep.:   1200, Loss: 1.152, Avg.Score: -28.00, Avg.LenOfSnake: 5.07, Max.LenOfSnake:  6.00 Time: 00:40:38
# Ep.:   1300, Loss: 1.006, Avg.Score: -28.00, Avg.LenOfSnake: 5.07, Max.LenOfSnake:  6.00 Time: 00:44:29
# Ep.:   1400, Loss: 1.050, Avg.Score: -30.00, Avg.LenOfSnake: 5.00, Max.LenOfSnake:  5.00 Time: 00:48:18
# Ep.:   1500, Loss: 1.172, Avg.Score: -26.00, Avg.LenOfSnake: 5.13, Max.LenOfSnake:  8.00 Time: 00:52:06
# Ep.:   1600, Loss: 1.388, Avg.Score: -24.00, Avg.LenOfSnake: 5.20, Max.LenOfSnake:  7.00 Time: 00:55:50
# Ep.:   1700, Loss: 1.129, Avg.Score: -27.00, Avg.LenOfSnake: 5.10, Max.LenOfSnake:  6.00 Time: 00:59:38
# Ep.:   1800, Loss: 1.311, Avg.Score: -27.00, Avg.LenOfSnake: 5.10, Max.LenOfSnake:  6.00 Time: 01:03:27
# Ep.:   1900, Loss: 1.155, Avg.Score: -24.00, Avg.LenOfSnake: 5.20, Max.LenOfSnake:  6.00 Time: 01:07:17
# Ep.:   2000, Loss: 1.841, Avg.Score: -26.00, Avg.LenOfSnake: 5.13, Max.LenOfSnake:  7.00 Time: 01:11:47
# Ep.:   2100, Loss: 1.569, Avg.Score: -26.00, Avg.LenOfSnake: 5.13, Max.LenOfSnake:  7.00 Time: 01:16:06
# Ep.:   2200, Loss: 1.336, Avg.Score: -24.00, Avg.LenOfSnake: 5.20, Max.LenOfSnake:  6.00 Time: 01:20:13
# Ep.:   2300, Loss: 1.377, Avg.Score: -22.00, Avg.LenOfSnake: 5.27, Max.LenOfSnake:  7.00 Time: 01:24:09
# Ep.:   2400, Loss: 1.473, Avg.Score: -25.00, Avg.LenOfSnake: 5.17, Max.LenOfSnake:  7.00 Time: 01:28:13
# Ep.:   2500, Loss: 1.280, Avg.Score: -22.00, Avg.LenOfSnake: 5.27, Max.LenOfSnake:  7.00 Time: 01:32:13
# Ep.:   2600, Loss: 0.972, Avg.Score: -25.00, Avg.LenOfSnake: 5.17, Max.LenOfSnake:  7.00 Time: 01:36:14
# Ep.:   2700, Loss: 1.812, Avg.Score: -19.00, Avg.LenOfSnake: 5.37, Max.LenOfSnake:  7.00 Time: 01:40:19
# Ep.:   2800, Loss: 2.163, Avg.Score: -13.00, Avg.LenOfSnake: 5.57, Max.LenOfSnake:  9.00 Time: 01:44:30
# Ep.:   2900, Loss: 1.528, Avg.Score: -15.00, Avg.LenOfSnake: 5.50, Max.LenOfSnake:  7.00 Time: 01:48:46
# Ep.:   3000, Loss: 1.369, Avg.Score: -19.00, Avg.LenOfSnake: 5.37, Max.LenOfSnake:  8.00 Time: 01:53:02

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('length of scores: ', len(scores), ', len of avg_scores: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg score on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# length of scores:  3001 , len of avg_scores:  3001

# %%
ax1 = fig.add_subplot(121)
plt.plot(np.arange(1, len(avg_len_of_snake)+1), avg_len_of_snake, label="Avg Len of Snake")
plt.plot(np.arange(1, len(max_len_of_snake)+1), max_len_of_snake, label="Max Len of Snake")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Length of Snake')
plt.xlabel('Episodes #')
plt.show()
